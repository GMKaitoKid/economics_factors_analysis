# %%
# !pip install fredapi
# Out:
# Collecting fredapi
#   Downloading fredapi-0.5.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: pandas in c:\users\asus\desktop\sample_project\env\lib\site-packages (from fredapi) (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\asus\desktop\sample_project\env\lib\site-packages (from pandas->fredapi) (2.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\asus\desktop\sample_project\env\lib\site-packages (from pandas->fredapi) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\desktop\sample_project\env\lib\site-packages (from pandas->fredapi) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\desktop\sample_project\env\lib\site-packages (from pandas->fredapi) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\asus\desktop\sample_project\env\lib\site-packages (from python-dateutil>=2.8.2->pandas->fredapi) (1.16.0)
# Downloading fredapi-0.5.2-py3-none-any.whl (11 kB)
# Installing collected packages: fredapi
# Successfully installed fredapi-0.5.2

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px 

plt.style.use('fivethirtyeight')
pd.options.display.max_columns = 500
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
from fredapi import Fred
fred_key = 'fc1154fefdce4b338294cfabe0430371'

# %% [markdown]
# # 1. Create the Fred Object

# %%
fred = Fred(api_key=fred_key)

# %% [markdown]
# # 2. Search for economic data

# %%
sp_search = fred.search('S&P', order_by='popularity')

# %%
sp_search.shape
# Out:
# (1000, 15)

# %%
sp_search
# Out:
#                                 id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2          BAMLH0A0HYM2     2025-01-21   2025-01-21
# CSUSHPINSA              CSUSHPINSA     2025-01-21   2025-01-21
# SP500                        SP500     2025-01-21   2025-01-21
# BAMLH0A0HYM2EY      BAMLH0A0HYM2EY     2025-01-21   2025-01-21
# BAMLC0A0CM              BAMLC0A0CM     2025-01-21   2025-01-21
# ...                            ...            ...          ...
# DDDI12SMA156NWDB  DDDI12SMA156NWDB     2025-01-21   2025-01-21
# Q03069USQ605NNBR  Q03069USQ605NNBR     2025-01-21   2025-01-21
# CSHICPCZA156NRUG  CSHICPCZA156NRUG     2025-01-21   2025-01-21
# CSHXCPVEA156NRUG  CSHXCPVEA156NRUG     2025-01-21   2025-01-21
# CSHMCPNPA156NRUG  CSHMCPNPA156NRUG     2025-01-21   2025-01-21
#
#                                                               title  \
# series id
# BAMLH0A0HYM2      ICE BofA US High Yield Index Option-Adjusted S...
# CSUSHPINSA        S&P CoreLogic Case-Shiller U.S. National Home ...
# SP500                                                       S&P 500
# BAMLH0A0HYM2EY         ICE BofA US High Yield Index Effective Yield
# BAMLC0A0CM        ICE BofA US Corporate Index Option-Adjusted Sp...
# ...                                                             ...
# DDDI12SMA156NWDB  Private Credit by Deposit Money Banks and Othe...
# Q03069USQ605NNBR  Revenue Freight Tons Originated, Less Than Car...
# CSHICPCZA156NRUG  Share of Gross Capital Formation at Current Pu...
# CSHXCPVEA156NRUG  Share of Merchandise Exports at Current Purcha...
# CSHMCPNPA156NRUG  Share of Merchandise Imports at Current Purcha...
#
#                  observation_start observation_end     frequency  \
# series id
# BAMLH0A0HYM2            1996-12-31      2025-01-16  Daily, Close
# CSUSHPINSA              1987-01-01      2024-10-01       Monthly
# SP500                   2015-01-20      2025-01-17  Daily, Close
# BAMLH0A0HYM2EY          1996-12-31      2025-01-16  Daily, Close
# BAMLC0A0CM              1996-12-31      2025-01-16  Daily, Close
# ...                            ...             ...           ...
# DDDI12SMA156NWDB        2001-01-01      2020-01-01        Annual
# Q03069USQ605NNBR        1920-01-01      1943-07-01     Quarterly
# CSHICPCZA156NRUG        1990-01-01      2019-01-01        Annual
# CSHXCPVEA156NRUG        1950-01-01      2019-01-01        Annual
# CSHMCPNPA156NRUG        1960-01-01      2019-01-01        Annual
#
#                  frequency_short               units         units_short  \
# series id
# BAMLH0A0HYM2                   D             Percent                   %
# CSUSHPINSA                     M  Index Jan 2000=100  Index Jan 2000=100
# SP500                          D               Index               Index
# BAMLH0A0HYM2EY                 D             Percent                   %
# BAMLC0A0CM                     D             Percent                   %
# ...                          ...                 ...                 ...
# DDDI12SMA156NWDB               A             Percent                   %
# Q03069USQ605NNBR               Q   Thousands of Tons      Thous. Of Tons
# CSHICPCZA156NRUG               A             Percent                   %
# CSHXCPVEA156NRUG               A             Percent                   %
# CSHMCPNPA156NRUG               A             Percent                   %
#
#                       seasonal_adjustment seasonal_adjustment_short  \
# series id
# BAMLH0A0HYM2      Not Seasonally Adjusted                       NSA
# CSUSHPINSA        Not Seasonally Adjusted                       NSA
# SP500             Not Seasonally Adjusted                       NSA
# BAMLH0A0HYM2EY    Not Seasonally Adjusted                       NSA
# BAMLC0A0CM        Not Seasonally Adjusted                       NSA
# ...                                   ...                       ...
# DDDI12SMA156NWDB  Not Seasonally Adjusted                       NSA
# Q03069USQ605NNBR  Not Seasonally Adjusted                       NSA
# CSHICPCZA156NRUG  Not Seasonally Adjusted                       NSA
# CSHXCPVEA156NRUG  Not Seasonally Adjusted                       NSA
# CSHMCPNPA156NRUG  Not Seasonally Adjusted                       NSA
#
#                                last_updated popularity  \
# series id
# BAMLH0A0HYM2      2025-01-17 07:47:09-06:00         92
# CSUSHPINSA        2024-12-31 08:12:02-06:00         88
# SP500             2025-01-17 19:11:50-06:00         83
# BAMLH0A0HYM2EY    2025-01-17 07:47:12-06:00         82
# BAMLC0A0CM        2025-01-17 07:53:02-06:00         78
# ...                                     ...        ...
# DDDI12SMA156NWDB  2024-05-07 15:28:48-05:00          3
# Q03069USQ605NNBR  2012-08-16 14:05:10-05:00          3
# CSHICPCZA156NRUG  2021-11-08 13:36:33-06:00          3
# CSHXCPVEA156NRUG  2021-11-08 13:32:15-06:00          3
# CSHMCPNPA156NRUG  2021-11-08 13:33:11-06:00          3
#
#                                                               notes
# series id
# BAMLH0A0HYM2      The ICE BofA Option-Adjusted Spreads (OASs) ar...
# CSUSHPINSA        For more information regarding the index, plea...
# SP500             The observations for the S&P 500 represent the...
# BAMLH0A0HYM2EY    This data represents the effective yield of th...
# BAMLC0A0CM        The ICE BofA Option-Adjusted Spreads (OASs) ar...
# ...                                                             ...
# DDDI12SMA156NWDB  Private credit by deposit money banks and othe...
# Q03069USQ605NNBR  Source: Interstate Commerce Commission, Data F...
# CSHICPCZA156NRUG  Source ID: csh_i  When using these data in you...
# CSHXCPVEA156NRUG  Source ID: csh_x  When using these data in you...
# CSHMCPNPA156NRUG  Source ID: csh_m  When using these data in you...
#
# [1000 rows x 15 columns]

# %% [markdown]
# # 3. Pull Raw Data & Plot

# %%
sp500 = fred.get_series(series_id='SP500')

# %%
sp500.plot()
# Out:
# <Axes: >

# %%
sp500.plot(figsize=(10, 5), title='S&P 500', lw=2)
# Out:
# <Axes: title={'center': 'S&P 500'}>

# %% [markdown]
# # 4. Pull and Join Multiple Data series

# %%
unemp_results = fred.search('unemployment')

# %%
unemp_results
# Out:
#                                           id realtime_start realtime_end  \
# series id
# UNRATE                                UNRATE     2025-01-21   2025-01-21
# UNRATENSA                          UNRATENSA     2025-01-21   2025-01-21
# UNEMPLOY                            UNEMPLOY     2025-01-21   2025-01-21
# NROU                                    NROU     2025-01-21   2025-01-21
# CCSA                                    CCSA     2025-01-21   2025-01-21
# ...                                      ...            ...          ...
# LAUCN340030000000003A  LAUCN340030000000003A     2025-01-21   2025-01-21
# LMUNRRTTLUM156S              LMUNRRTTLUM156S     2025-01-21   2025-01-21
# LNS14000315                      LNS14000315     2025-01-21   2025-01-21
# LNU04032222                      LNU04032222     2025-01-21   2025-01-21
# LNU04032223                      LNU04032223     2025-01-21   2025-01-21
#
#                                                                    title  \
# series id
# UNRATE                                                 Unemployment Rate
# UNRATENSA                                              Unemployment Rate
# UNEMPLOY                                              Unemployment Level
# NROU                                    Noncyclical Rate of Unemployment
# CCSA                             Continued Claims (Insured Unemployment)
# ...                                                                  ...
# LAUCN340030000000003A             Unemployment Rate in Bergen County, NJ
# LMUNRRTTLUM156S        Infra-Annual Registered Unemployment and Job V...
# LNS14000315                            Unemployment Rate - Married Women
# LNU04032222            Unemployment Rate - Natural Resources, Constru...
# LNU04032223            Unemployment Rate - Farming, Fishing, and Fore...
#
#                       observation_start observation_end  \
# series id
# UNRATE                       1948-01-01      2024-12-01
# UNRATENSA                    1948-01-01      2024-12-01
# UNEMPLOY                     1948-01-01      2024-12-01
# NROU                         1949-01-01      2034-10-01
# CCSA                         1967-01-07      2025-01-04
# ...                                 ...             ...
# LAUCN340030000000003A        1990-01-01      2023-01-01
# LMUNRRTTLUM156S              1995-01-01      2023-12-01
# LNS14000315                  1955-01-01      2024-12-01
# LNU04032222                  2000-01-01      2024-12-01
# LNU04032223                  2000-01-01      2024-12-01
#
#                                      frequency frequency_short  \
# series id
# UNRATE                                 Monthly               M
# UNRATENSA                              Monthly               M
# UNEMPLOY                               Monthly               M
# NROU                                 Quarterly               Q
# CCSA                   Weekly, Ending Saturday               W
# ...                                        ...             ...
# LAUCN340030000000003A                   Annual               A
# LMUNRRTTLUM156S                        Monthly               M
# LNS14000315                            Monthly               M
# LNU04032222                            Monthly               M
# LNU04032223                            Monthly               M
#
#                                              units  \
# series id
# UNRATE                                     Percent
# UNRATENSA                                  Percent
# UNEMPLOY                      Thousands of Persons
# NROU                                       Percent
# CCSA                                        Number
# ...                                            ...
# LAUCN340030000000003A                      Percent
# LMUNRRTTLUM156S        Growth rate previous period
# LNS14000315                                Percent
# LNU04032222                                Percent
# LNU04032223                                Percent
#
#                                        units_short      seasonal_adjustment  \
# series id
# UNRATE                                           %      Seasonally Adjusted
# UNRATENSA                                        %  Not Seasonally Adjusted
# UNEMPLOY                         Thous. of Persons      Seasonally Adjusted
# NROU                                             %  Not Seasonally Adjusted
# CCSA                                        Number      Seasonally Adjusted
# ...                                            ...                      ...
# LAUCN340030000000003A                            %  Not Seasonally Adjusted
# LMUNRRTTLUM156S        Growth rate previous period      Seasonally Adjusted
# LNS14000315                                      %      Seasonally Adjusted
# LNU04032222                                      %  Not Seasonally Adjusted
# LNU04032223                                      %  Not Seasonally Adjusted
#
#                       seasonal_adjustment_short               last_updated  \
# series id
# UNRATE                                       SA  2025-01-10 07:49:03-06:00
# UNRATENSA                                   NSA  2025-01-10 07:49:09-06:00
# UNEMPLOY                                     SA  2025-01-10 07:49:04-06:00
# NROU                                        NSA  2024-07-01 12:01:04-05:00
# CCSA                                         SA  2025-01-16 07:33:03-06:00
# ...                                         ...                        ...
# LAUCN340030000000003A                       NSA  2024-05-01 10:48:38-05:00
# LMUNRRTTLUM156S                              SA  2024-04-10 11:07:38-05:00
# LNS14000315                                  SA  2025-01-10 07:49:36-06:00
# LNU04032222                                 NSA  2025-01-10 07:48:17-06:00
# LNU04032223                                 NSA  2025-01-10 07:48:09-06:00
#
#                       popularity  \
# series id
# UNRATE                        95
# UNRATENSA                     58
# UNEMPLOY                      71
# NROU                          69
# CCSA                          74
# ...                          ...
# LAUCN340030000000003A          0
# LMUNRRTTLUM156S                5
# LNS14000315                    9
# LNU04032222                    9
# LNU04032223                    9
#
#                                                                    notes
# series id
# UNRATE                 The unemployment rate represents the number of...
# UNRATENSA              The unemployment rate represents the number of...
# UNEMPLOY               The series comes from the 'Current Population ...
# NROU                   Starting with the July, 2021 report: An Update...
# CCSA                   Continued claims, also referred to as insured ...
# ...                                                                  ...
# LAUCN340030000000003A  These data come from the Current Population Su...
# LMUNRRTTLUM156S        OECD Data Filters:  REF_AREA: LUX MEASURE: REG...
# LNS14000315            To obtain estimates of women worker employment...
# LNU04032222            The series comes from the 'Current Population ...
# LNU04032223            The series comes from the 'Current Population ...
#
# [1000 rows x 15 columns]

# %%
unrate = fred.get_series('UNRATE')
unrate
# Out:
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5
#              ...
# 2024-08-01    4.2
# 2024-09-01    4.1
# 2024-10-01    4.1
# 2024-11-01    4.2
# 2024-12-01    4.1
# Length: 924, dtype: float64

# %%
# unrate.plot(lw='1')
# Out:
# <Axes: >

# %%
unemp_df = fred.search('unemployment rate state', filter=('frequency','Monthly'))
unemp_df = unemp_df.query('seasonal_adjustment == "Seasonally Adjusted" and units == "Percent"')
unemp_df = unemp_df.loc[unemp_df['title'].str.contains('Unemployment Rate')]

# %%
unemp_df
# Out:
#                                 id realtime_start realtime_end  \
# series id
# UNRATE                      UNRATE     2025-01-21   2025-01-21
# LNS14000006            LNS14000006     2025-01-21   2025-01-21
# CAUR                          CAUR     2025-01-21   2025-01-21
# TXUR                          TXUR     2025-01-21   2025-01-21
# M0892AUSM156SNBR  M0892AUSM156SNBR     2025-01-21   2025-01-21
# ...                            ...            ...          ...
# LNS14000026            LNS14000026     2025-01-21   2025-01-21
# LNS14000048            LNS14000048     2025-01-21   2025-01-21
# LNS14000089            LNS14000089     2025-01-21   2025-01-21
# M08311USM156SNBR  M08311USM156SNBR     2025-01-21   2025-01-21
# LNS14000150            LNS14000150     2025-01-21   2025-01-21
#
#                                                               title  \
# series id
# UNRATE                                            Unemployment Rate
# LNS14000006           Unemployment Rate - Black or African American
# CAUR                                Unemployment Rate in California
# TXUR                                     Unemployment Rate in Texas
# M0892AUSM156SNBR                Unemployment Rate for United States
# ...                                                             ...
# LNS14000026               Unemployment Rate - 20 Yrs. & over, Women
# LNS14000048                      Unemployment Rate - 25 Yrs. & over
# LNS14000089                          Unemployment Rate - 25-34 Yrs.
# M08311USM156SNBR  Unemployment Rate, Married Males, Spouse Prese...
# LNS14000150                         Unemployment Rate - Married Men
#
#                  observation_start observation_end frequency frequency_short  \
# series id
# UNRATE                  1948-01-01      2024-12-01   Monthly               M
# LNS14000006             1972-01-01      2024-12-01   Monthly               M
# CAUR                    1976-01-01      2024-11-01   Monthly               M
# TXUR                    1976-01-01      2024-11-01   Monthly               M
# M0892AUSM156SNBR        1929-04-01      1942-06-01   Monthly               M
# ...                            ...             ...       ...             ...
# LNS14000026             1948-01-01      2024-12-01   Monthly               M
# LNS14000048             1948-01-01      2024-12-01   Monthly               M
# LNS14000089             1948-01-01      2024-12-01   Monthly               M
# M08311USM156SNBR        1954-11-01      1968-01-01   Monthly               M
# LNS14000150             1955-01-01      2024-12-01   Monthly               M
#
#                     units units_short  seasonal_adjustment  \
# series id
# UNRATE            Percent           %  Seasonally Adjusted
# LNS14000006       Percent           %  Seasonally Adjusted
# CAUR              Percent           %  Seasonally Adjusted
# TXUR              Percent           %  Seasonally Adjusted
# M0892AUSM156SNBR  Percent           %  Seasonally Adjusted
# ...                   ...         ...                  ...
# LNS14000026       Percent           %  Seasonally Adjusted
# LNS14000048       Percent           %  Seasonally Adjusted
# LNS14000089       Percent           %  Seasonally Adjusted
# M08311USM156SNBR  Percent           %  Seasonally Adjusted
# LNS14000150       Percent           %  Seasonally Adjusted
#
#                  seasonal_adjustment_short               last_updated  \
# series id
# UNRATE                                  SA  2025-01-10 07:49:03-06:00
# LNS14000006                             SA  2025-01-10 07:49:03-06:00
# CAUR                                    SA  2024-12-23 09:31:02-06:00
# TXUR                                    SA  2024-12-23 09:31:03-06:00
# M0892AUSM156SNBR                        SA  2012-08-17 14:26:06-05:00
# ...                                    ...                        ...
# LNS14000026                             SA  2025-01-10 07:49:38-06:00
# LNS14000048                             SA  2025-01-10 07:49:38-06:00
# LNS14000089                             SA  2025-01-10 07:49:44-06:00
# M08311USM156SNBR                        SA  2012-08-17 14:28:17-05:00
# LNS14000150                             SA  2025-01-10 07:49:37-06:00
#
#                  popularity                                              notes
# series id
# UNRATE                   95  The unemployment rate represents the number of...
# LNS14000006              72  The series comes from the 'Current Population ...
# CAUR                     64                                               None
# TXUR                     56                                               None
# M0892AUSM156SNBR         54  Series Is Presented Here As Three Variables--(...
# ...                     ...                                                ...
# LNS14000026               6  To obtain estimates of women worker employment...
# LNS14000048               6  The series comes from the 'Current Population ...
# LNS14000089               6  The series comes from the 'Current Population ...
# M08311USM156SNBR          6  Beginning In 1960 Data Include Alaska And Hawa...
# LNS14000150               5  The series comes from the 'Current Population ...
#
# [98 rows x 15 columns]

# %%
all_results = []
for myid in unemp_df.index:
    results = fred.get_series(myid)
    results = results.to_frame(name=myid)
    all_results.append(results)
unemp_results = pd.concat(all_results, axis=1)
